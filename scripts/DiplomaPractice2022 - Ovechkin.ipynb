# %%
from bs4 import BeautifulSoup
import pandas as pd
from datetime import datetime

# %%
with open('C:/Users/VG/Saved Games/Desktop/dippractice/data/sports/en/ovechkin.html', 'rb') as html:
    soup = BeautifulSoup(html)

# %%
count = 0
df_comments=[]

# %%
def MyBS4commentScrapper(bs4commentbox):  
    global count
    
    commenttext = bs4commentbox.find("div","HTMLContent-root-5770ce4668399900d87c06ad10ba71a5 htmlContent-root-fe3506b39eaecd1a685ceda5e1292c4d coral coral-content coral-comment-content").text

    nickdate = bs4commentbox.find("div","Box-root-acb8bd0953d79380f99868ba1e9c06f2 Flex-root-e30c492230d1edb681fe55ee4db5c12e Flex-flex-d2ca733e3f89034ac350e74ab398ca2c Flex-wrap-6d1b6ac029ed4bb936d308545730f2ca Flex-alignCenter-26c1ac1572ede070f23436e4a05f81bd")
    nick = bs4commentbox.find("span","Username-root-c00565d265d60c03a8fd24001a836d2b").text
    date = bs4commentbox.find("time","RelativeTime-root-d30b4f3b231d2f240c2f63990321529f Timestamp-text-b943991e0f8e51bb4bdba60eabe40535 Comment-timestamp-b603d74501b527b492dba3e2561137cb coral coral-timestamp coral-comment-timestamp")["datetime"]

    reactbox = bs4commentbox.find("div","Box-root-acb8bd0953d79380f99868ba1e9c06f2 Flex-root-e30c492230d1edb681fe55ee4db5c12e CommentContainer-actionBar-8f945503291a6fbc016fbde66cee912e Flex-flex-d2ca733e3f89034ac350e74ab398ca2c Flex-halfItemGutter-a202fcab1dcbec6c729d74b586859a0d Flex-justifySpaceBetween-1e1ecf12d82a80d36b234d1261a4a513 Flex-alignCenter-26c1ac1572ede070f23436e4a05f81bd Flex-directionRow-2454f15d2085c2be40d132bad0acd66d gutter")
    likesbox = reactbox.find("span","ReactionButton-totalReactions-5c75d792070e447916aec4f5cebb1972")

    if likesbox == None:
        likescount = 0
    else:
        likescount = int(likesbox.text)

    repliesbox = bs4commentbox.find("div","Box-root-acb8bd0953d79380f99868ba1e9c06f2 HorizontalGutter-root-42028c0a7886c844bb9f01763cc43000")
    
    
    if repliesbox == None:     
        repliesindexes = []
        repliescount = 0
    else:
        replies = repliesbox.find_all("div", "Box-root-acb8bd0953d79380f99868ba1e9c06f2 HorizontalGutter-root-42028c0a7886c844bb9f01763cc43000",recursive=False)
        repliescount = len(replies)
        repliesindexes = []
        
        for reply in replies:
            
            MyBS4commentScrapper(reply)
            repliesindexes.append(count-1)
            
        
    df_comments.append([count,commenttext,nick,date,likescount,False,repliescount,repliesindexes])   
    count = count + 1

# %%
commentboxes = soup.find_all("div","Box-root-acb8bd0953d79380f99868ba1e9c06f2 HorizontalGutter-root-42028c0a7886c844bb9f01763cc43000 AllCommentsTabCommentContainer-borderedCommentNotSeen-dc042ede476ae67068a90f1b6f6c567e")
# "Box-root-acb8bd0953d79380f99868ba1e9c06f2 HorizontalGutter-root-42028c0a7886c844bb9f01763cc43000 HorizontalGutter-full-680598106a6954360bcd94b9d3839ca7"

for comment in commentboxes:
    isbasecomment = True
    MyBS4commentScrapper(comment)
    df_comments[count-1][5] = True

# %%
ovechkinData=pd.DataFrame(df_comments,columns=["countID","CommentText","Nickname","Date","LikesCount","IsBaseComment","RepliesCount","RepliesID"])
ovechkinData["Date"] = ovechkinData["Date"].apply(lambda x: datetime.strptime(x,"%Y-%m-%dT%H:%M:%S.%fZ"))

ovechkinData
# Out:
#      countID                                        CommentText  \
# 0          0  Here's another perspective. I saw this in the ...
# 1          1  Yeah worrying about Ovechkin's family is cring...
# 2          2  I thought this guy's take on Putin was interes...
# 3          3  Please feel free to present evidence that Alex...
# 4          4                                           Cool it.
# 5          5  Simply pointing out ignorance, which people do...
# 6          6  No, you're not simply pointing out ignorance, ...
# 7          7  Imagine making such shockingly ignorant commen...
# 8          8  As an immigration lawyer with a high-end pract...
# 9          9  The situation inside Russia is bad, but it's n...
# 10        10  And there you have it, folks!Just like I was m...
# 11        11  I love Ovie, but the thought that a guy of his...
# 12        12  If Puty O'Tutin can pocket 7 goals on the Russ...
# 13        13  This thread just…..hurts.   Worse than chattin...
# 14        14  No. Cheating keeps you out or if was borderlin...
# 15        15  The following possibility dawned on me. Could ...
# 16        16  Lots of fake news (see post with Slava's tweet...
# 17        17  What about Steve Eminger and Josh Green, Larry...
# 18        18  If Dmitri Khristich hasn’t criticized Ovechkin...
# 19        19  That probably depends on who takes action firs...
# 20        20  Well, many people have openly talked about how...
# 21        21  I don’t think Putin let’s people within 30ft o...
# 22        22  A bridge to war.  (DuPont means "of the bridge...
# 23        23           Dupont's became Dupont's because of war.
# 24        24  One of the things with this war I'm wondering ...
# 25        25  Whether or not his support was coerced or deli...
# 26        26  he knows what went on with PanarinNothing real...
# 27        27  We all know that Ovi is one of four Russian pl...
# 28        28  I can't place hardly any blame on Ovi (nor, fo...
# 29        29  I think there is way too much guilt by associa...
# ..       ...                                                ...
# 113      113  He suits their anti-Ovi rhetoric at the moment...
# 114      114  Baltimore math teacher who got his media crede...
# 115      115                               Slava is… the worst
# 116      116  Slava in the words of Luke Adomonis of Japers ...
# 117      117                                        Bewmer? :-)
# 118      118  I dunno man. Let me check my gud poast guideli...
# 119      119                                     Whaddya think?
# 120      120  I don't speak meme.I have no idea who that dud...
# 121      121              (I knew that) … your intent, that is.
# 122      122                 OK boomer. :)(They are on purpose)
# 123      123                    Your spell check is killing me.
# 124      124           This is a solid taek. I like this poast.
# 125      125  I realize I’m going to sound like an Ovi apolo...
# 126      126  Yup but if you put something on social media i...
# 127      127  He's on social media relatively rarely so it h...
# 128      128  To mean this is more proof that social media i...
# 129      129  Based on what I'm seeing, this isn't about Ove...
# 130      130  There were many Canes fans outraged by that pa...
# 131      131  They were outraged until they saw deAngelo run...
# 132      132  Yup. It was hilarious how outraged they were t...
# 133      133  Yuck. Lose all respect for any Caps fan who sw...
# 134      134  Plenty of folks have shown up at Capital One i...
# 135      135                                               HAH!
# 136      136      Somewhere, Bryce Harper is waving and is sad.
# 126                            NathanS77 2022-03-04 15:17:57.733           0
# 127                            CapsFan75 2022-03-04 13:54:24.209           0
# 128                            NathanS77 2022-03-04 04:55:39.668           0
# 129                             Forsch31 2022-03-03 21:49:50.649           2
# 130                            CapsFan75 2022-03-04 13:56:46.064           0
# 131                        MikeL-Pivonka 2022-03-04 21:09:10.720           0
# 132                            CapsFan75 2022-03-05 02:40:25.464           0
# 133                            NathanS77 2022-03-04 04:53:47.846           0
# 134                            CapsFan75 2022-03-04 04:35:55.915           2
# 135                            NathanS77 2022-03-04 15:32:25.547           0
# 136                         capsfan4life 2022-03-04 12:49:22.582           0
# 137                            NathanS77 2022-03-03 23:33:39.390           0
# 138                        MikeL-Pivonka 2022-03-04 21:09:55.838           1
# 139                        larry.e.ramey 2022-03-04 15:18:00.126           2
# 140                            CapsFan75 2022-03-03 21:21:53.961           0
# 141                          ChrisCaps19 2022-03-03 21:01:37.311           4
# 142                           coolhand18 2022-03-03 20:32:15.034           0
#
#      IsBaseComment  RepliesCount                  RepliesID
# 0             True             0                         []
# 1             True             0                         []
# 2             True             0                         []
# 3            False             0                         []
# 4            False             0                         []
# 5            False             0                         []
# 6            False             0                         []
# 7            False             3                  [4, 5, 6]
# 8            False             2                     [3, 7]
# 9            False             0                         []
# 10           False             2                     [8, 9]
# 11            True             1                       [10]
# 12            True             0                         []
# 13            True             0                         []
# 14           False             0                         []
# 15            True             1                       [14]
# 16            True             0                         []
# 17           False             0                         []
# 18            True             1                       [17]
# 19           False             0                         []
# 20           False             0                         []
# 21           False             1                       [20]
# 22           False             0                         []
# 23           False             1                       [22]
# 24            True             3               [19, 21, 23]
# 25           False             0                         []
# 26           False             0                         []
# 27            True             2                   [25, 26]
# 28           False             0                         []
# 29            True             1                       [28]
# ..             ...           ...                        ...
# 113          False             1                      [112]
# 114          False             0                         []
# 115          False             1                      [114]
# 116          False             2                 [113, 115]
# 117          False             0                         []
# 118          False             0                         []
# 119          False             0                         []
# 120          False             0                         []
# 121          False             0                         []
# 122          False             5  [117, 118, 119, 120, 121]
# 123          False             1                      [122]
# 124          False             1                      [123]
# 125           True             2                 [116, 124]
# 126          False             0                         []
# 127          False             1                      [126]
# 128          False             1                      [127]
# 129           True             1                      [128]
# 130          False             0                         []
# 131          False             0                         []
# 132          False             0                         []
# 133          False             3            [130, 131, 132]
# 134          False             1                      [133]
# 135          False             0                         []
# 136          False             1                      [135]
# 137          False             2                 [134, 136]
# 138          False             0                         []
# 139          False             1                      [138]
# 140           True             2                 [137, 139]
# 141           True             0                         []
# 142           True             0                         []
#
# [143 rows x 8 columns]

# %%
# True = 1 , False = 0
b = True
for index, row in ovechkinData.iterrows():
    b = b * (index == row["countID"])

if b == True : 
    ovechkinData = ovechkinData.drop(["countID"], axis = 1) 
    print("id and countID match")
# Out:
# id and countID match

# %%
ovechkinData.to_csv(path_or_buf='C:/Users/VG/Saved Games/Desktop/dippractice/data/sports/en/ovechkin.csv')
